# %%
import pandas as pd
from datetime import date
from random import choices, randint, choice

from init import item_codes, warehouse_codes, start_date, number_of_inbounds

# %%
current_date = start_date
current_PO_number = 1
current_PO_item_number = 1
outbound_frequency = 0.1 # the higher this number, the less frequently goods is sold in a day
combined_PO_frequency = 0.9 # the lower this number, the more items are combined in a SO

outbounds = []
for i in range(number_of_inbounds):

    # New date?
    if choices(population=[True,False],weights=[outbound_frequency, 1 - outbound_frequency])[0]:
        current_date = current_date + pd.DateOffset(days=1)

    # New SO?
    if choices(population=[True,False],weights=[combined_PO_frequency, 1 - combined_PO_frequency])[0]:
        current_PO_number += 1
        current_PO_item_number = 1
    zeros = "0"*(3-len(str(current_PO_number)))
    SO_number = 'SO' + zeros + str(current_PO_number)
    SO_item_number = SO_number + '-' + str(current_PO_item_number)
    current_PO_item_number += 1

    # Select a random Item sold outbound
    item_outbound = choice(item_codes)

    # Select a random Warehouse outbound from
    warehouse_outbound = choice(warehouse_codes)

    outbounds.append([SO_item_number,SO_number,current_date,warehouse_outbound,item_outbound,randint(1,100)*10])

df = pd.DataFrame(outbounds,columns=["Element_Code","Element_Number","Date","Warehouse_Code","Item_Code","Outbound_Amount"])
df["Date"] = pd.to_datetime(df["Date"])
df
# Out:
#    Element_Code Element_Number       Date Warehouse_Code Item_Code  \
# 0       SO002-1          SO002 2025-01-01          WH001   Item001
# 1       SO003-1          SO003 2025-01-01          WH002   Item006
# 2       SO004-1          SO004 2025-01-01          WH003   Item003
# 3       SO005-1          SO005 2025-01-01          WH002   Item005
# 4       SO006-1          SO006 2025-01-01          WH001   Item014
# ..          ...            ...        ...            ...       ...
# 95      SO085-1          SO085 2025-01-10          WH002   Item009
# 96      SO086-1          SO086 2025-01-10          WH002   Item006
# 97      SO087-1          SO087 2025-01-10          WH001   Item003
# 98      SO088-1          SO088 2025-01-10          WH003   Item006
# 99      SO089-1          SO089 2025-01-10          WH002   Item014
#
#     Outbound_Amount
# 0               970
# 1                40
# 2               790
# 3               780
# 4               480
# ..              ...
# 95              800
# 96               30
# 97              130
# 98              940
# 99              700
#
# [100 rows x 6 columns]

# %%
import os

# Ensure the target directory exists before saving the file
os.makedirs("../Datasets", exist_ok=True)

# Save DataFrame as CSV into existing directory
df.to_csv("../Datasets/Inbound.csv", index=False)
