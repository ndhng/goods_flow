# %%
import pandas as pd
from anyio.lowlevel import cancel_shielded_checkpoint

from Data_Setup import init

# %%
# Initialize filter: starting stock & filter item code

last_stock_date = init.start_date - pd.Timedelta(days=1)
last_stock_date = last_stock_date.strftime('%Y-%m-%d')
item_code_filter = 'Item001'

# %%
# Read inbound & outbound data, include "Element_Type", filter out item code, and change the value of outbound amount to negative

inbound_data = pd.read_csv("Datasets/Inbound.csv")
inbound_data["Element_Type"] = "Purchase Order Item"
inbound_data = inbound_data[inbound_data['Item_Code'] == item_code_filter]

outbound_data = pd.read_csv("Datasets/Outbound.csv")
outbound_data['Amount'] = outbound_data['Amount'] * -1
outbound_data["Element_Type"] = "Sales Order Item"
outbound_data = outbound_data[outbound_data['Item_Code'] == item_code_filter]

# %%
merged_data = pd.concat([inbound_data, outbound_data], ignore_index=True)
merged_data.sort_values(by=['Date'], inplace=True, ignore_index=True)
merged_data[["Date","Element_Code","Element_Type","Warehouse_Code","Amount"]]
# Out:
#           Date Element_Code         Element_Type Warehouse_Code  Amount
# 0   2025-01-02      PO003-1  Purchase Order Item          WH002     570
# 1   2025-01-03      SO002-1     Sales Order Item          WH002    -490
# 2   2025-01-04      SO005-1     Sales Order Item          WH003    -520
# 3   2025-01-04      SO005-2     Sales Order Item          WH002    -870
# 4   2025-01-04      SO006-1     Sales Order Item          WH001     -50
# 5   2025-01-10      SO009-1     Sales Order Item          WH001    -650
# 6   2025-01-14      PO020-2  Purchase Order Item          WH001     800
# 7   2025-01-21      PO032-1  Purchase Order Item          WH002     640
# 8   2025-01-21      SO024-1     Sales Order Item          WH002    -770
# 9   2025-01-23      SO025-1     Sales Order Item          WH001    -740
# 10  2025-01-30      SO029-3     Sales Order Item          WH001    -620
# 11  2025-02-02      SO032-1     Sales Order Item          WH001    -850
# 12  2025-02-10      SO038-1     Sales Order Item          WH001    -590
# 13  2025-02-21      SO053-1     Sales Order Item          WH002    -110
# 14  2025-02-23      PO071-1  Purchase Order Item          WH002     440
# 15  2025-02-27      SO063-1     Sales Order Item          WH002    -360

# %%
available_stock = pd.read_csv("Datasets/Available_Stock.csv")
available_stock = available_stock[available_stock['Item_Code'] == item_code_filter]
available_stock = available_stock[available_stock['Date'] == last_stock_date]

available_stock
# Out:
#           Date Warehouse_Code Item_Code  Stock_Amount
# 0   2024-12-31          WH001   Item001          5800
# 15  2024-12-31          WH002   Item001          3100
# 30  2024-12-31          WH003   Item001          3200
# 45  2024-12-31          WH004   Item001          1600

# %%
columns = ['Date', 'Element_Code', 'Element_Type', 'Warehouse_Code']
for warehouse in init.warehouse_codes:
    columns.append(warehouse)

dashboard = pd.DataFrame(columns=columns)

first_row = [last_stock_date, None,'Available Stock', None, None, None, None, None]
dashboard.loc[0] = first_row

for index, row in available_stock.iterrows():
    WH = row['Warehouse_Code']
    available = row['Stock_Amount']
    dashboard.loc[0,WH] = available


dashboard
# Out:
#          Date Element_Code     Element_Type Warehouse_Code WH001 WH002 WH003  \
# 0  2024-12-31         None  Available Stock           None  5800  3100  3200
#
#   WH004
# 0  1600

# %%
dashboard = dashboard.merge(right = merged_data, how='outer', on=['Date','Element_Code','Element_Type','Warehouse_Code'])
dashboard
# Out:
#           Date Element_Code         Element_Type Warehouse_Code WH001 WH002  \
# 0   2024-12-31         None      Available Stock           None  5800  3100
# 1   2025-01-02      PO003-1  Purchase Order Item          WH002   NaN   NaN
# 2   2025-01-03      SO002-1     Sales Order Item          WH002   NaN   NaN
# 3   2025-01-04      SO005-1     Sales Order Item          WH003   NaN   NaN
# 4   2025-01-04      SO005-2     Sales Order Item          WH002   NaN   NaN
# 5   2025-01-04      SO006-1     Sales Order Item          WH001   NaN   NaN
# 6   2025-01-10      SO009-1     Sales Order Item          WH001   NaN   NaN
# 7   2025-01-14      PO020-2  Purchase Order Item          WH001   NaN   NaN
# 8   2025-01-21      PO032-1  Purchase Order Item          WH002   NaN   NaN
# 9   2025-01-21      SO024-1     Sales Order Item          WH002   NaN   NaN
# 10  2025-01-23      SO025-1     Sales Order Item          WH001   NaN   NaN
# 11  2025-01-30      SO029-3     Sales Order Item          WH001   NaN   NaN
# 12  2025-02-02      SO032-1     Sales Order Item          WH001   NaN   NaN
# 13  2025-02-10      SO038-1     Sales Order Item          WH001   NaN   NaN
# 14  2025-02-21      SO053-1     Sales Order Item          WH002   NaN   NaN
# 15  2025-02-23      PO071-1  Purchase Order Item          WH002   NaN   NaN
# 16  2025-02-27      SO063-1     Sales Order Item          WH002   NaN   NaN
#
#    WH003 WH004 Element_Number Item_Code  Amount
# 0   3200  1600            NaN       NaN     NaN
# 1    NaN   NaN          PO003   Item001   570.0
# 2    NaN   NaN          SO002   Item001  -490.0
# 3    NaN   NaN          SO005   Item001  -520.0
# 4    NaN   NaN          SO005   Item001  -870.0
# 5    NaN   NaN          SO006   Item001   -50.0
# 6    NaN   NaN          SO009   Item001  -650.0
# 7    NaN   NaN          PO020   Item001   800.0
# 8    NaN   NaN          PO032   Item001   640.0
# 9    NaN   NaN          SO024   Item001  -770.0
# 10   NaN   NaN          SO025   Item001  -740.0
# 11   NaN   NaN          SO029   Item001  -620.0
# 12   NaN   NaN          SO032   Item001  -850.0
# 13   NaN   NaN          SO038   Item001  -590.0
# 14   NaN   NaN          SO053   Item001  -110.0
# 15   NaN   NaN          PO071   Item001   440.0
# 16   NaN   NaN          SO063   Item001  -360.0

# %%
dashboard = dashboard.drop(columns=['Element_Number', 'Item_Code'], errors='ignore')

cols = dashboard.columns.tolist()
cols.insert(4, cols.pop(cols.index('Amount')))
dashboard = dashboard[cols]
dashboard
# Out:
#           Date Element_Code         Element_Type Warehouse_Code  Amount WH001  \
# 0   2024-12-31         None      Available Stock           None     NaN  5800
# 1   2025-01-02      PO003-1  Purchase Order Item          WH002   570.0   NaN
# 2   2025-01-03      SO002-1     Sales Order Item          WH002  -490.0   NaN
# 3   2025-01-04      SO005-1     Sales Order Item          WH003  -520.0   NaN
# 4   2025-01-04      SO005-2     Sales Order Item          WH002  -870.0   NaN
# 5   2025-01-04      SO006-1     Sales Order Item          WH001   -50.0   NaN
# 6   2025-01-10      SO009-1     Sales Order Item          WH001  -650.0   NaN
# 7   2025-01-14      PO020-2  Purchase Order Item          WH001   800.0   NaN
# 8   2025-01-21      PO032-1  Purchase Order Item          WH002   640.0   NaN
# 9   2025-01-21      SO024-1     Sales Order Item          WH002  -770.0   NaN
# 10  2025-01-23      SO025-1     Sales Order Item          WH001  -740.0   NaN
# 11  2025-01-30      SO029-3     Sales Order Item          WH001  -620.0   NaN
# 12  2025-02-02      SO032-1     Sales Order Item          WH001  -850.0   NaN
# 13  2025-02-10      SO038-1     Sales Order Item          WH001  -590.0   NaN
# 14  2025-02-21      SO053-1     Sales Order Item          WH002  -110.0   NaN
# 15  2025-02-23      PO071-1  Purchase Order Item          WH002   440.0   NaN
# 16  2025-02-27      SO063-1     Sales Order Item          WH002  -360.0   NaN
#
#    WH002 WH003 WH004
# 0   3100  3200  1600
# 1    NaN   NaN   NaN
# 2    NaN   NaN   NaN
# 3    NaN   NaN   NaN
# 4    NaN   NaN   NaN
# 5    NaN   NaN   NaN
# 6    NaN   NaN   NaN
# 7    NaN   NaN   NaN
# 8    NaN   NaN   NaN
# 9    NaN   NaN   NaN
# 10   NaN   NaN   NaN
# 11   NaN   NaN   NaN
# 12   NaN   NaN   NaN
# 13   NaN   NaN   NaN
# 14   NaN   NaN   NaN
# 15   NaN   NaN   NaN
# 16   NaN   NaN   NaN

# %%
for index, row in dashboard.iterrows():
    if index == 0:
        continue
    else:
        for col in dashboard.columns[5:]:
            if row['Warehouse_Code'] == col:
                dashboard.loc[index,col] = row['Amount'] + dashboard.loc[index-1,col]
            else:
                dashboard.loc[index,col] = dashboard.loc[index-1,col]

dashboard
# Out:
#           Date Element_Code         Element_Type Warehouse_Code  Amount  \
# 0   2024-12-31         None      Available Stock           None     NaN
# 1   2025-01-02      PO003-1  Purchase Order Item          WH002   570.0
# 2   2025-01-03      SO002-1     Sales Order Item          WH002  -490.0
# 3   2025-01-04      SO005-1     Sales Order Item          WH003  -520.0
# 4   2025-01-04      SO005-2     Sales Order Item          WH002  -870.0
# 5   2025-01-04      SO006-1     Sales Order Item          WH001   -50.0
# 6   2025-01-10      SO009-1     Sales Order Item          WH001  -650.0
# 7   2025-01-14      PO020-2  Purchase Order Item          WH001   800.0
# 8   2025-01-21      PO032-1  Purchase Order Item          WH002   640.0
# 9   2025-01-21      SO024-1     Sales Order Item          WH002  -770.0
# 10  2025-01-23      SO025-1     Sales Order Item          WH001  -740.0
# 11  2025-01-30      SO029-3     Sales Order Item          WH001  -620.0
# 12  2025-02-02      SO032-1     Sales Order Item          WH001  -850.0
# 13  2025-02-10      SO038-1     Sales Order Item          WH001  -590.0
# 14  2025-02-21      SO053-1     Sales Order Item          WH002  -110.0
# 15  2025-02-23      PO071-1  Purchase Order Item          WH002   440.0
# 16  2025-02-27      SO063-1     Sales Order Item          WH002  -360.0
#
#      WH001   WH002   WH003 WH004
# 0     5800    3100    3200  1600
# 1     5800  3670.0    3200  1600
# 2     5800  3180.0    3200  1600
# 3     5800  3180.0  2680.0  1600
# 4     5800  2310.0  2680.0  1600
# 5   5750.0  2310.0  2680.0  1600
# 6   5100.0  2310.0  2680.0  1600
# 7   5900.0  2310.0  2680.0  1600
# 8   5900.0  2950.0  2680.0  1600
# 9   5900.0  2180.0  2680.0  1600
# 10  5160.0  2180.0  2680.0  1600
# 11  4540.0  2180.0  2680.0  1600
# 12  3690.0  2180.0  2680.0  1600
# 13  3100.0  2180.0  2680.0  1600
# 14  3100.0  2070.0  2680.0  1600
# 15  3100.0  2510.0  2680.0  1600
# 16  3100.0  2150.0  2680.0  1600
